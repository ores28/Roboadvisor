# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg as AR

# Load dataset
df = pd.read_csv("gibf1_stable_sections.csv")

# Scaling factor for error sensitivity adjustment
SCALING_FACTOR = 100

# Dictionary to store all section-wise data
section_data = {
    "df_section": {},
    "best_k": {},
    "aic": {},
    "model": {},
    "predictions": {},
    "reconstruction_error": {},
    "scaled_reconstruction_error": {},
    "iFMII": {}
}

# Storage for all results
all_results = []

# Iterate through sections
for section in range(1, 44):
    # Filter data for this section and reset index
    df_section = df[df["Stable_Section"] == section].copy().reset_index(drop=True)
    section_data["df_section"][section] = df_section

    print(f"\n🔹 Processing df{section} (Stable_Section {section})...")

    # Ensure there are enough data points
    if len(df_section) < 10:
        print(f"⚠️ Not enough data for df{section}. Skipping...")
        all_results.append({"Section": section, "Best_k": None, "AIC": None, "iFMII": None})
        continue

    # Step 1: Find the best k using AIC
    best_k = 1
    best_aic = float("inf")

    for k in range(1, min(6, len(df_section) - 5)):  # Ensure valid k values
        try:
            model = AR(df_section["closePrice"], lags=k).fit()
            if model.aic < best_aic:
                best_aic = model.aic
                best_k = k
        except Exception as e:
            print(f"⚠️ AR model failed for k={k} in df{section}: {e}")
            continue

    section_data["best_k"][section] = best_k
    section_data["aic"][section] = best_aic
    print(f"✅ Best AR order (k) for df{section}: {best_k} (AIC = {best_aic})")

    # Step 2: Fit the best AR model
    try:
        print(f"🔧 Fitting AR({best_k}) model on df{section}...")
        section_data["model"][section] = AR(df_section["closePrice"], lags=best_k).fit()
    except Exception as e:
        print(f"⚠️ AR model fitting failed for df{section}: {e}")
        continue

    # Fix Prediction Issue: Ensure Proper Indexing
    train_size = len(df_section) - best_k

    if train_size <= 0:
        print(f"⚠️ Not enough data points for prediction in df{section}. Skipping...")
        continue

    try:
        print(f"🔮 Predicting for df{section} (Train size: {train_size}, Total size: {len(df_section)})...")

        # Make sure start and end indices are within valid range
        start_idx = max(train_size, 0)
        end_idx = len(df_section) - 1

        section_data["predictions"][section] = section_data["model"][section].predict(start=start_idx, end=end_idx)

        print(f"📊 Predictions for df{section}:\n{section_data['predictions'][section]}")

    except Exception as e:
        print(f"⚠️ Prediction failed for df{section}: {e}")
        continue

    # If predictions are NaN, print possible causes
    if section_data["predictions"][section].isna().sum() == len(section_data["predictions"][section]):
        print(f"⚠️ All predictions are NaN for df{section}. Possible issues:")
        print(f"   - Check if data index is properly reset (Try df_section.reset_index())")
        print(f"   - Ensure start={start_idx}, end={end_idx} are valid indices")
        print(f"   - Dataset size: {len(df_section)}, Best k: {best_k}")
        continue

    # Step 3: Compute Reconstruction Error
    actual_values = df_section["closePrice"].values[start_idx:]  # Align with predictions
    reconstructed_values = section_data["predictions"][section].values

    # Ensure predictions and actual_values have the same length
    if len(actual_values) != len(reconstructed_values):
        print(f"⚠️ Mismatch in lengths for df{section}. Actual: {len(actual_values)}, Predicted: {len(reconstructed_values)}")
        continue

    # Compute squared reconstruction error
    section_data["reconstruction_error"][section] = np.square(actual_values - reconstructed_values)
    print(f"🔄 Reconstruction Error for df{section}:\n{section_data['reconstruction_error'][section]}")

    # Step 4: Scale Reconstruction Error Instead of Normalizing
    section_data["scaled_reconstruction_error"][section] = section_data["reconstruction_error"][section] * SCALING_FACTOR

    # Compute iFMII using the scaled reconstruction error
    section_data["iFMII"][section] = np.nanmean(section_data["scaled_reconstruction_error"][section])

    # Print scaled reconstruction error
    print(f"📈 Scaled Reconstruction Error for df{section}:\n{section_data['scaled_reconstruction_error'][section]}")
    print(f"📉 Mean iFMII for df{section}: {section_data['iFMII'][section]}")

    # Step 5: Store Results for CSV Output
    for idx, (actual, predicted, error, scaled_error) in enumerate(zip(actual_values, reconstructed_values, 
                                                                       section_data["reconstruction_error"][section], 
                                                                       section_data["scaled_reconstruction_error"][section])):
        all_results.append({
            "Section": section,
            "Index": idx + start_idx,
            "Actual_ClosePrice": actual,
            "Predicted_ClosePrice": predicted,
            "Reconstruction_Error": error,
            "Scaled_Reconstruction_Error": scaled_error,
            "iFMII": section_data["iFMII"][section]
        })

# Convert results to a DataFrame and save to CSV
df_results = pd.DataFrame(all_results)
df_results.to_csv("gibf1_section_predictions.csv", index=False)

print("\n🔍 Final Results Saved to gibf1_section_predictions.csv")
# Out:
# 🔹 Processing df1 (Stable_Section 1)...
# ✅ Best AR order (k) for df1: 1 (AIC = 2.262959188703989)
# 🔧 Fitting AR(1) model on df1...
# 🔮 Predicting for df1 (Train size: 19, Total size: 20)...
# 📊 Predictions for df1:
# 19    8.307491
# dtype: float64
# 🔄 Reconstruction Error for df1:
# [0.01155426]
# 📈 Scaled Reconstruction Error for df1:
# [1.15542556]
# 📉 Mean iFMII for df1: 1.1554255577911408
#
# 🔹 Processing df2 (Stable_Section 2)...
# ✅ Best AR order (k) for df2: 1 (AIC = 2.838305299504773)
# 🔧 Fitting AR(1) model on df2...
# 🔮 Predicting for df2 (Train size: 19, Total size: 20)...
# 📊 Predictions for df2:
# 19    8.378938
# dtype: float64
# 🔄 Reconstruction Error for df2:
# [0.02926217]
# 📈 Scaled Reconstruction Error for df2:
# [2.92621749]
# 📉 Mean iFMII for df2: 2.92621748767626
#
# 🔹 Processing df3 (Stable_Section 3)...
# ✅ Best AR order (k) for df3: 2 (AIC = -6.803899706707822)
# 🔧 Fitting AR(2) model on df3...
# 🔮 Predicting for df3 (Train size: 18, Total size: 20)...
# 📊 Predictions for df3:
# 18    8.319595
# 19    8.326380
# dtype: float64
# 🔄 Reconstruction Error for df3:
# [5.77946324e-02 4.07075341e-05]
# 📈 Scaled Reconstruction Error for df3:
# [5.77946324e+00 4.07075341e-03]
# 📉 Mean iFMII for df3: 2.8917669978582827
#
# 🔹 Processing df4 (Stable_Section 4)...
# ✅ Best AR order (k) for df4: 1 (AIC = -8.572326837927388)
# 🔧 Fitting AR(1) model on df4...
# 🔮 Predicting for df4 (Train size: 19, Total size: 20)...
# 📊 Predictions for df4:
# 19    8.33174
# dtype: float64
# 🔄 Reconstruction Error for df4:
# [0.00841616]
# 📈 Scaled Reconstruction Error for df4:
# [0.84161566]
# 📉 Mean iFMII for df4: 0.8416156569794072
#
# 🔹 Processing df5 (Stable_Section 5)...
# ✅ Best AR order (k) for df5: 1 (AIC = -9.430218113122834)
# 🔧 Fitting AR(1) model on df5...
# 🔮 Predicting for df5 (Train size: 19, Total size: 20)...
# 📊 Predictions for df5:
# 19    8.342322
# dtype: float64
# 🔄 Reconstruction Error for df5:
# [0.01261627]
# 📈 Scaled Reconstruction Error for df5:
# [1.26162693]
# 📉 Mean iFMII for df5: 1.2616269255280335
#
# 🔹 Processing df6 (Stable_Section 6)...
# ✅ Best AR order (k) for df6: 5 (AIC = -22.739717890656863)
# 🔧 Fitting AR(5) model on df6...
# 🔮 Predicting for df6 (Train size: 15, Total size: 20)...
# 📊 Predictions for df6:
# 15    8.353415
# 16    8.185979
# 17    8.278647
# 18    8.246853
# 19    8.225195
# dtype: float64
# 🔄 Reconstruction Error for df6:
# [0.01523131 0.00409871 0.00082068 0.00135811 0.00063476]
# 📈 Scaled Reconstruction Error for df6:
# [1.52313079 0.40987089 0.08206758 0.13581075 0.06347634]
# 📉 Mean iFMII for df6: 0.44287126939965427
#
# 🔹 Processing df7 (Stable_Section 7)...
# ✅ Best AR order (k) for df7: 4 (AIC = -26.78945306782134)
# 🔧 Fitting AR(4) model on df7...
# 🔮 Predicting for df7 (Train size: 16, Total size: 20)...
# 📊 Predictions for df7:
# 16    8.279199
# 17    8.247884
# 18    8.213024
# 19    8.202500
# dtype: float64
# 🔄 Reconstruction Error for df7:
# [0.0008526  0.00143517 0.00016964 0.00030624]
# 📈 Scaled Reconstruction Error for df7:
# [0.08526005 0.14351743 0.01696353 0.03062388]
# 📉 Mean iFMII for df7: 0.06909122301398134
#
# 🔹 Processing df8 (Stable_Section 8)...
# ✅ Best AR order (k) for df8: 3 (AIC = -26.62228246536347)
# 🔧 Fitting AR(3) model on df8...
# 🔮 Predicting for df8 (Train size: 17, Total size: 20)...
# 📊 Predictions for df8:
# 17    8.227813
# 18    8.230970
# 19    8.279197
# dtype: float64
# 🔄 Reconstruction Error for df8:
# [6.10477659e-05 2.85711522e-02 1.93758101e-02]
# 📈 Scaled Reconstruction Error for df8:
# [0.00610478 2.85711522 1.93758101]
# 📉 Mean iFMII for df8: 1.6002670010985816
#
# 🔹 Processing df9 (Stable_Section 9)...
# ✅ Best AR order (k) for df9: 2 (AIC = -19.694247404622445)
# 🔧 Fitting AR(2) model on df9...
# 🔮 Predicting for df9 (Train size: 18, Total size: 20)...
# 📊 Predictions for df9:
# 18    8.234547
# 19    8.418954
# dtype: float64
# 🔄 Reconstruction Error for df9:
# [0.00893915 0.07898677]
# 📈 Scaled Reconstruction Error for df9:
# [0.89391504 7.89867696]
# 📉 Mean iFMII for df9: 4.3962960005007785
#
# 🔹 Processing df10 (Stable_Section 10)...
# ✅ Best AR order (k) for df10: 1 (AIC = -10.859134279730199)
# 🔧 Fitting AR(1) model on df10...
# 🔮 Predicting for df10 (Train size: 19, Total size: 20)...
# 📊 Predictions for df10:
# 19    8.251792
# dtype: float64
# 🔄 Reconstruction Error for df10:
# [0.01249737]
# 📈 Scaled Reconstruction Error for df10:
# [1.24973681]
# 📉 Mean iFMII for df10: 1.2497368132628455
#
# 🔹 Processing df11 (Stable_Section 11)...
# ✅ Best AR order (k) for df11: 1 (AIC = -1.8378622554888686)
# 🔧 Fitting AR(1) model on df11...
# 🔮 Predicting for df11 (Train size: 19, Total size: 20)...
# 📊 Predictions for df11:
# 19    8.491956
# dtype: float64
# 🔄 Reconstruction Error for df11:
# [0.10761273]
# 📈 Scaled Reconstruction Error for df11:
# [10.76127321]
# 📉 Mean iFMII for df11: 10.761273208923159
#
# 🔹 Processing df12 (Stable_Section 12)...
# ✅ Best AR order (k) for df12: 1 (AIC = -0.754875397365204)
# 🔧 Fitting AR(1) model on df12...
# 🔮 Predicting for df12 (Train size: 19, Total size: 20)...
# 📊 Predictions for df12:
# 19    8.658617
# dtype: float64
# 🔄 Reconstruction Error for df12:
# [0.03289991]
# 📈 Scaled Reconstruction Error for df12:
# [3.28999072]
# 📉 Mean iFMII for df12: 3.2899907226623566
#
# 🔹 Processing df13 (Stable_Section 13)...
# ✅ Best AR order (k) for df13: 4 (AIC = 0.6653943251724925)
# 🔧 Fitting AR(4) model on df13...
# 🔮 Predicting for df13 (Train size: 16, Total size: 20)...
# 📊 Predictions for df13:
# 16    8.637030
# 17    8.593621
# 18    8.494188
# 19    8.148593
# dtype: float64
# 🔄 Reconstruction Error for df13:
# [0.02991858 0.01354416 0.05962766 0.02292396]
# 📈 Scaled Reconstruction Error for df13:
# [2.99185789 1.35441645 5.96276561 2.29239648]
# 📉 Mean iFMII for df13: 3.150359107884227
#
# 🔹 Processing df14 (Stable_Section 14)...
# ✅ Best AR order (k) for df14: 1 (AIC = -3.2311581499485715)
# 🔧 Fitting AR(1) model on df14...
# 🔮 Predicting for df14 (Train size: 19, Total size: 20)...
# 📊 Predictions for df14:
# 19    8.381206
# dtype: float64
# 🔄 Reconstruction Error for df14:
# [0.01926382]
# 📈 Scaled Reconstruction Error for df14:
# [1.9263823]
# 📉 Mean iFMII for df14: 1.9263823000514755
#
# 🔹 Processing df15 (Stable_Section 15)...
# ✅ Best AR order (k) for df15: 1 (AIC = -4.929907039515365)
# 🔧 Fitting AR(1) model on df15...
# 🔮 Predicting for df15 (Train size: 19, Total size: 20)...
# 📊 Predictions for df15:
# 19    8.361608
# dtype: float64
# 🔄 Reconstruction Error for df15:
# [0.00340961]
# 📈 Scaled Reconstruction Error for df15:
# [0.34096052]
# 📉 Mean iFMII for df15: 0.3409605160741716
#
# 🔹 Processing df16 (Stable_Section 16)...
# ✅ Best AR order (k) for df16: 2 (AIC = -6.646597814434333)
# 🔧 Fitting AR(2) model on df16...
# 🔮 Predicting for df16 (Train size: 18, Total size: 20)...
# 📊 Predictions for df16:
# 18    8.648161
# 19    8.515787
# dtype: float64
# 🔄 Reconstruction Error for df16:
# [0.00338275 0.03090105]
# 📈 Scaled Reconstruction Error for df16:
# [0.33827467 3.09010521]
# 📉 Mean iFMII for df16: 1.7141899408668868
#
# 🔹 Processing df17 (Stable_Section 17)...
# ✅ Best AR order (k) for df17: 2 (AIC = -4.224835481184485)
# 🔧 Fitting AR(2) model on df17...
# 🔮 Predicting for df17 (Train size: 18, Total size: 20)...
# 📊 Predictions for df17:
# 18    8.314868
# 19    8.455772
# dtype: float64
# 🔄 Reconstruction Error for df17:
# [0.00123427 0.00311046]
# 📈 Scaled Reconstruction Error for df17:
# [0.12342733 0.3110463 ]
# 📉 Mean iFMII for df17: 0.21723681234688108
#
# 🔹 Processing df18 (Stable_Section 18)...
# ✅ Best AR order (k) for df18: 1 (AIC = -5.794341755906613)
# 🔧 Fitting AR(1) model on df18...
# 🔮 Predicting for df18 (Train size: 19, Total size: 20)...
# 📊 Predictions for df18:
# 19    8.376842
# dtype: float64
# 🔄 Reconstruction Error for df18:
# [0.01141524]
# 📈 Scaled Reconstruction Error for df18:
# [1.14152355]
# 📉 Mean iFMII for df18: 1.1415235457065362
#
# 🔹 Processing df19 (Stable_Section 19)...
# ✅ Best AR order (k) for df19: 1 (AIC = -3.286398472759167)
# 🔧 Fitting AR(1) model on df19...
# 🔮 Predicting for df19 (Train size: 19, Total size: 20)...
# 📊 Predictions for df19:
# 19    8.424859
# dtype: float64
# 🔄 Reconstruction Error for df19:
# [0.00720103]
# 📈 Scaled Reconstruction Error for df19:
# [0.72010283]
# 📉 Mean iFMII for df19: 0.7201028344996658
#
# 🔹 Processing df20 (Stable_Section 20)...
# ✅ Best AR order (k) for df20: 1 (AIC = -2.043936776847872)
# 🔧 Fitting AR(1) model on df20...
# 🔮 Predicting for df20 (Train size: 19, Total size: 20)...
# 📊 Predictions for df20:
# 19    8.42987
# dtype: float64
# 🔄 Reconstruction Error for df20:
# [0.04834287]
# 📈 Scaled Reconstruction Error for df20:
# [4.8342874]
# 📉 Mean iFMII for df20: 4.834287400910978
#
# 🔹 Processing df21 (Stable_Section 21)...
# ✅ Best AR order (k) for df21: 2 (AIC = -1.96144015754847)
# 🔧 Fitting AR(2) model on df21...
# 🔮 Predicting for df21 (Train size: 18, Total size: 20)...
# 📊 Predictions for df21:
# 18    8.484418
# 19    8.433263
# dtype: float64
# 🔄 Reconstruction Error for df21:
# [0.03400987 0.00869797]
# 📈 Scaled Reconstruction Error for df21:
# [3.40098666 0.86979735]
# 📉 Mean iFMII for df21: 2.135392003403459
#
# 🔹 Processing df22 (Stable_Section 22)...
# ✅ Best AR order (k) for df22: 1 (AIC = -2.6381965439424864)
# 🔧 Fitting AR(1) model on df22...
# 🔮 Predicting for df22 (Train size: 19, Total size: 20)...
# 📊 Predictions for df22:
# 19    8.430712
# dtype: float64
# 🔄 Reconstruction Error for df22:
# [0.0443996]
# 📈 Scaled Reconstruction Error for df22:
# [4.43995994]
# 📉 Mean iFMII for df22: 4.439959938493355
#
# 🔹 Processing df23 (Stable_Section 23)...
# ✅ Best AR order (k) for df23: 1 (AIC = -2.8176801446730657)
# 🔧 Fitting AR(1) model on df23...
# 🔮 Predicting for df23 (Train size: 19, Total size: 20)...
# 📊 Predictions for df23:
# 19    8.399084
# dtype: float64
# 🔄 Reconstruction Error for df23:
# [0.03207122]
# 📈 Scaled Reconstruction Error for df23:
# [3.20712247]
# 📉 Mean iFMII for df23: 3.207122465334158
#
# 🔹 Processing df24 (Stable_Section 24)...
# ✅ Best AR order (k) for df24: 5 (AIC = -6.583525954684077)
# 🔧 Fitting AR(5) model on df24...
# 🔮 Predicting for df24 (Train size: 15, Total size: 20)...
# 📊 Predictions for df24:
# 15    8.354800
# 16    8.364008
# 17    8.276927
# 18    8.316011
# 19    8.277469
# dtype: float64
# 🔄 Reconstruction Error for df24:
# [0.00021903 0.00409698 0.00324068 0.00921818 0.0033027 ]
# 📈 Scaled Reconstruction Error for df24:
# [0.02190275 0.40969832 0.32406796 0.92181778 0.33026989]
# 📉 Mean iFMII for df24: 0.40155134116627506
#
# 🔹 Processing df25 (Stable_Section 25)...
# ✅ Best AR order (k) for df25: 2 (AIC = -14.430006932368798)
# 🔧 Fitting AR(2) model on df25...
# 🔮 Predicting for df25 (Train size: 18, Total size: 20)...
# 📊 Predictions for df25:
# 18    8.316249
# 19    8.385467
# dtype: float64
# 🔄 Reconstruction Error for df25:
# [0.00288912 0.02088972]
# 📈 Scaled Reconstruction Error for df25:
# [0.28891212 2.08897223]
# 📉 Mean iFMII for df25: 1.188942175293117
#
# 🔹 Processing df26 (Stable_Section 26)...
# ✅ Best AR order (k) for df26: 1 (AIC = -15.845164937047556)
# 🔧 Fitting AR(1) model on df26...
# 🔮 Predicting for df26 (Train size: 19, Total size: 20)...
# 📊 Predictions for df26:
# 19    8.561563
# dtype: float64
# 🔄 Reconstruction Error for df26:
# [0.00172749]
# 📈 Scaled Reconstruction Error for df26:
# [0.1727494]
# 📉 Mean iFMII for df26: 0.17274940079596854
#
# 🔹 Processing df27 (Stable_Section 27)...
# ✅ Best AR order (k) for df27: 2 (AIC = -15.235914007797753)
# 🔧 Fitting AR(2) model on df27...
# 🔮 Predicting for df27 (Train size: 18, Total size: 20)...
# 📊 Predictions for df27:
# 18    8.259389
# 19    8.434694
# dtype: float64
# 🔄 Reconstruction Error for df27:
# [0.01977136 0.07038709]
# 📈 Scaled Reconstruction Error for df27:
# [1.97713593 7.03870947]
# 📉 Mean iFMII for df27: 4.507922698403176
#
# 🔹 Processing df28 (Stable_Section 28)...
# ✅ Best AR order (k) for df28: 3 (AIC = 13.037939899314253)
# 🔧 Fitting AR(3) model on df28...
# 🔮 Predicting for df28 (Train size: 17, Total size: 20)...
# 📊 Predictions for df28:
# 17    9.872320
# 18    9.934828
# 19    9.894966
# dtype: float64
# 🔄 Reconstruction Error for df28:
# [0.03324046 0.07553033 0.0342123 ]
# 📈 Scaled Reconstruction Error for df28:
# [3.32404637 7.5530333  3.42122986]
# 📉 Mean iFMII for df28: 4.76610317578534
#
# 🔹 Processing df29 (Stable_Section 29)...
# ✅ Best AR order (k) for df29: 5 (AIC = 3.363934414911558)
# 🔧 Fitting AR(5) model on df29...
# 🔮 Predicting for df29 (Train size: 15, Total size: 20)...
# 📊 Predictions for df29:
# 15     9.915383
# 16     9.750825
# 17     9.841200
# 18     9.909296
# 19    10.048279
# dtype: float64
# 🔄 Reconstruction Error for df29:
# [0.04218219 0.05720447 0.00238146 0.07328044 0.00079969]
# 📈 Scaled Reconstruction Error for df29:
# [4.21821867 5.72044723 0.23814634 7.32804401 0.07996918]
# 📉 Mean iFMII for df29: 3.5169650851159857
#
# 🔹 Processing df30 (Stable_Section 30)...
# ✅ Best AR order (k) for df30: 1 (AIC = 1.6210144285587926)
# 🔧 Fitting AR(1) model on df30...
# 🔮 Predicting for df30 (Train size: 19, Total size: 20)...
# 📊 Predictions for df30:
# 19    10.010775
# dtype: float64
# 🔄 Reconstruction Error for df30:
# [0.03580614]
# 📈 Scaled Reconstruction Error for df30:
# [3.58061389]
# 📉 Mean iFMII for df30: 3.580613890015379
#
# 🔹 Processing df31 (Stable_Section 31)...
# ✅ Best AR order (k) for df31: 1 (AIC = -0.6005245534755606)
# 🔧 Fitting AR(1) model on df31...
# 🔮 Predicting for df31 (Train size: 19, Total size: 20)...
# 📊 Predictions for df31:
# 19    10.168161
# dtype: float64
# 🔄 Reconstruction Error for df31:
# [0.02827821]
# 📈 Scaled Reconstruction Error for df31:
# [2.82782117]
# 📉 Mean iFMII for df31: 2.8278211727237945
#
# 🔹 Processing df32 (Stable_Section 32)...
# ✅ Best AR order (k) for df32: 3 (AIC = -9.599754970583856)
# 🔧 Fitting AR(3) model on df32...
# 🔮 Predicting for df32 (Train size: 17, Total size: 20)...
# 📊 Predictions for df32:
# 17    10.266121
# 18    10.096361
# 19    10.233115
# dtype: float64
# 🔄 Reconstruction Error for df32:
# [0.00703571 0.00069493 0.00282121]
# 📈 Scaled Reconstruction Error for df32:
# [0.7035705  0.0694927  0.28212144]
# 📉 Mean iFMII for df32: 0.35172821687397393
#
# 🔹 Processing df33 (Stable_Section 33)...
# ✅ Best AR order (k) for df33: 1 (AIC = -10.705158832978835)
# 🔧 Fitting AR(1) model on df33...
# 🔮 Predicting for df33 (Train size: 19, Total size: 20)...
# 📊 Predictions for df33:
# 19    10.175382
# dtype: float64
# 🔄 Reconstruction Error for df33:
# [0.03075896]
# 📈 Scaled Reconstruction Error for df33:
# [3.07589555]
# 📉 Mean iFMII for df33: 3.075895554644559
#
# 🔹 Processing df34 (Stable_Section 34)...
# ✅ Best AR order (k) for df34: 1 (AIC = -11.979089157403216)
# 🔧 Fitting AR(1) model on df34...
# 🔮 Predicting for df34 (Train size: 19, Total size: 20)...
# 📊 Predictions for df34:
# 19    10.115937
# dtype: float64
# 🔄 Reconstruction Error for df34:
# [0.00410409]
# 📈 Scaled Reconstruction Error for df34:
# [0.4104089]
# 📉 Mean iFMII for df34: 0.41040889970019034
#
# 🔹 Processing df35 (Stable_Section 35)...
# ✅ Best AR order (k) for df35: 2 (AIC = 4.349284574457133)
# 🔧 Fitting AR(2) model on df35...
# 🔮 Predicting for df35 (Train size: 18, Total size: 20)...
# 📊 Predictions for df35:
# 18    9.306883
# 19    9.148918
# dtype: float64
# 🔄 Reconstruction Error for df35:
# [0.08813968 0.01021751]
# 📈 Scaled Reconstruction Error for df35:
# [8.81396833 1.02175101]
# 📉 Mean iFMII for df35: 4.917859673964982
#
# 🔹 Processing df36 (Stable_Section 36)...
# ✅ Best AR order (k) for df36: 1 (AIC = 6.800230515023239)
# 🔧 Fitting AR(1) model on df36...
# 🔮 Predicting for df36 (Train size: 19, Total size: 20)...
# 📊 Predictions for df36:
# 19    9.580011
# dtype: float64
# 🔄 Reconstruction Error for df36:
# [0.04409557]
# 📈 Scaled Reconstruction Error for df36:
# [4.40955704]
# 📉 Mean iFMII for df36: 4.4095570438281575
#
# 🔹 Processing df37 (Stable_Section 37)...
# ✅ Best AR order (k) for df37: 5 (AIC = 4.2678407390833115)
# 🔧 Fitting AR(5) model on df37...
# 🔮 Predicting for df37 (Train size: 15, Total size: 20)...
# 📊 Predictions for df37:
# 15    9.179330
# 16    9.316772
# 17    9.679510
# 18    9.816875
# 19    9.615073
# dtype: float64
# 🔄 Reconstruction Error for df37:
# [0.00499422 0.08021805 0.01220808 0.02344731 0.00062866]
# 📈 Scaled Reconstruction Error for df37:
# [0.49942233 8.02180525 1.22080807 2.34473054 0.0628664 ]
# 📉 Mean iFMII for df37: 2.4299265159281793
#
# 🔹 Processing df38 (Stable_Section 38)...
# ✅ Best AR order (k) for df38: 1 (AIC = 4.192908813374562)
# 🔧 Fitting AR(1) model on df38...
# 🔮 Predicting for df38 (Train size: 19, Total size: 20)...
# 📊 Predictions for df38:
# 19    10.047176
# dtype: float64
# 🔄 Reconstruction Error for df38:
# [0.06109593]
# 📈 Scaled Reconstruction Error for df38:
# [6.1095933]
# 📉 Mean iFMII for df38: 6.109593297810393
#
# 🔹 Processing df39 (Stable_Section 39)...
# ✅ Best AR order (k) for df39: 5 (AIC = 1.5023145903433193)
# 🔧 Fitting AR(5) model on df39...
# 🔮 Predicting for df39 (Train size: 15, Total size: 20)...
# 📊 Predictions for df39:
# 15    10.008584
# 16    10.011463
# 17     9.969829
# 18    10.039563
# 19     9.538314
# dtype: float64
# 🔄 Reconstruction Error for df39:
# [0.09697968 0.04471657 0.00010346 0.01947794 0.02007492]
# 📈 Scaled Reconstruction Error for df39:
# [9.69796763 4.47165726 0.01034578 1.94779424 2.00749229]
# 📉 Mean iFMII for df39: 3.6270514422633093
#
# 🔹 Processing df40 (Stable_Section 40)...
# ✅ Best AR order (k) for df40: 4 (AIC = -2.1300625299796465)
# 🔧 Fitting AR(4) model on df40...
# 🔮 Predicting for df40 (Train size: 16, Total size: 20)...
# 📊 Predictions for df40:
# 16     9.961303
# 17    10.028982
# 18     9.538577
# 19     9.797875
# dtype: float64
# 🔄 Reconstruction Error for df40:
# [0.00034957 0.01663641 0.02000044 0.00143448]
# 📈 Scaled Reconstruction Error for df40:
# [0.03495715 1.66364062 2.00004401 0.14344801]
# 📉 Mean iFMII for df40: 0.9605224462755309
#
# 🔹 Processing df41 (Stable_Section 41)...
# ✅ Best AR order (k) for df41: 1 (AIC = -32.12973751721706)
# 🔧 Fitting AR(1) model on df41...
# 🔮 Predicting for df41 (Train size: 19, Total size: 20)...
# 📊 Predictions for df41:
# 19    10.011683
# dtype: float64
# 🔄 Reconstruction Error for df41:
# [0.0003355]
# 📈 Scaled Reconstruction Error for df41:
# [0.03355045]
# 📉 Mean iFMII for df41: 0.03355044975614925
#
# 🔹 Processing df42 (Stable_Section 42)...
# ✅ Best AR order (k) for df42: 1 (AIC = -21.16601578679392)
# 🔧 Fitting AR(1) model on df42...
# 🔮 Predicting for df42 (Train size: 19, Total size: 20)...
# 📊 Predictions for df42:
# 19    9.992156
# dtype: float64
# 🔄 Reconstruction Error for df42:
# [0.11032776]
# 📈 Scaled Reconstruction Error for df42:
# [11.03277598]
# 📉 Mean iFMII for df42: 11.032775980480423
#
# 🔹 Processing df43 (Stable_Section 43)...
# ✅ Best AR order (k) for df43: 2 (AIC = -16.055286808063126)
# 🔧 Fitting AR(2) model on df43...
# 🔮 Predicting for df43 (Train size: 18, Total size: 20)...
# 📊 Predictions for df43:
# 18    9.871171
# 19    9.755248
# dtype: float64
# 🔄 Reconstruction Error for df43:
# [0.00506533 0.00305239]
# 📈 Scaled Reconstruction Error for df43:
# [0.5065334  0.30523944]
# 📉 Mean iFMII for df43: 0.40588641965913247
#
# 🔍 Final Results Saved to gibf1_section_predictions.csv

# %%
# Rank iFMII in descending order (higher iFMII = higher anomaly)
df_results["iFMII_rank"] = df_results["iFMII"].rank(ascending=False, method="min")

# Calculate p-value using the rank
total_predictions = len(df_results)
df_results["p_value_linear"] = df_results["iFMII_rank"] / total_predictions

# Save the updated results to CSV
df_results.to_csv("gibf1_section_predictions.csv", index=False)

print("\n✅ Results saved to section_predictio.csv")
# Out:
# ✅ Results saved to section_predictio.csv
